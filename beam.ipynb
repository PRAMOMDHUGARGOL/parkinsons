# %%
import numpy as np
import pandas
import math as math 
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
a=np.arange(0,426.72,30.48,dtype=float)
b=a/2
print(b)
print(a)
for x in a : 
    for y in b:
        c=np.arctan(b/a)
        f=np.degrees(c)
    print(f)
    break
plt.plot(a,f,label='positive',color='r')
plt.xlabel("cm")
plt.ylabel("degrees")
plt.plot(a,-f,label="negative",color='g')
plt.grid(True,color="k")
plt.show()
# Out:
# [  0.    15.24  30.48  45.72  60.96  76.2   91.44 106.68 121.92 137.16
#  152.4  167.64 182.88 198.12]
# [  0.    30.48  60.96  91.44 121.92 152.4  182.88 213.36 243.84 274.32
#  304.8  335.28 365.76 396.24]
# [        nan 26.56505118 26.56505118 26.56505118 26.56505118 26.56505118
#  26.56505118 26.56505118 26.56505118 26.56505118 26.56505118 26.56505118
#  26.56505118 26.56505118]
